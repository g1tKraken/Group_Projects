# %%
import pandas as pd
import requests
import logging
import json
from alpha_vantage.timeseries import TimeSeries
from datetime import date, timedelta

# %%
logging.basicConfig(format='%(asctime)s : %(lineno)d : %(levelname)s : %(message)s', level=logging.DEBUG)

# %%
covid_response = requests.get("https://covidtracking.com/api/states/daily").json()
covid_dataframe = pd.DataFrame(covid_response)
covid_dataframe
# Out:
# 2020-05-08 17:45:56,913 : 959 : DEBUG : Starting new HTTPS connection (1): covidtracking.com:443
# 2020-05-08 17:45:56,999 : 437 : DEBUG : https://covidtracking.com:443 "GET /api/states/daily HTTP/1.1" 200 298423
#           date state  positive  negative  pending  hospitalizedCurrently  \
# 0     20200508    AK     377.0   25096.0      NaN                   16.0
# 1     20200508    AL    9221.0  110893.0      NaN                    NaN
# 2     20200508    AR    3694.0   60300.0      NaN                   70.0
# 3     20200508    AS       0.0      83.0      NaN                    NaN
# 4     20200508    AZ   10526.0  109381.0      NaN                  730.0
# ...        ...   ...       ...       ...      ...                    ...
# 3596  20200126    WA       1.0       NaN      NaN                    NaN
# 3597  20200125    WA       1.0       NaN      NaN                    NaN
# 3598  20200124    WA       1.0       NaN      NaN                    NaN
# 3599  20200123    WA       1.0       NaN      NaN                    NaN
# 3600  20200122    WA       1.0       NaN      NaN                    NaN
#
#       hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                        NaN             NaN              NaN
# 1                     1207.0             NaN            454.0
# 2                      466.0             NaN              NaN
# 3                        NaN             NaN              NaN
# 4                     1482.0           295.0              NaN
# ...                      ...             ...              ...
# 3596                     NaN             NaN              NaN
# 3597                     NaN             NaN              NaN
# 3598                     NaN             NaN              NaN
# 3599                     NaN             NaN              NaN
# 3600                     NaN             NaN              NaN
#
#       onVentilatorCurrently  ...  hospitalized   total totalTestResults  \
# 0                       NaN  ...           NaN   25473            25473
# 1                       NaN  ...        1207.0  120114           120114
# 2                      14.0  ...         466.0   63994            63994
# 3                       NaN  ...           NaN      83               83
# 4                     197.0  ...        1482.0  119907           119907
# ...                     ...  ...           ...     ...              ...
# 3596                    NaN  ...           NaN       1                1
# 3597                    NaN  ...           NaN       1                1
# 3598                    NaN  ...           NaN       1                1
# 3599                    NaN  ...           NaN       1                1
# 3600                    NaN  ...           NaN       1                1
#
#       posNeg fips deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0      25473   02           0.0                   0.0            1129.0
# 1     120114   01          26.0                  29.0            4618.0
# 2      63994   05           1.0                   4.0            3916.0
# 3         83   60           0.0                   0.0               0.0
# 4     119907   04          67.0                  33.0            8240.0
# ...      ...  ...           ...                   ...               ...
# 3596       1   53           0.0                   0.0               0.0
# 3597       1   53           0.0                   0.0               0.0
# 3598       1   53           0.0                   0.0               0.0
# 3599       1   53           0.0                   0.0               0.0
# 3600       1   53           NaN                   NaN               NaN
#
#       positiveIncrease  totalTestResultsIncrease
# 0                  3.0                    1132.0
# 1                323.0                    4941.0
# 2                 83.0                    3999.0
# 3                  0.0                       0.0
# 4                581.0                    8821.0
# ...                ...                       ...
# 3596               0.0                       0.0
# 3597               0.0                       0.0
# 3598               0.0                       0.0
# 3599               0.0                       0.0
# 3600               NaN                       NaN
#
# [3601 rows x 27 columns]

# %%
#alphavantage api

# Your key here
key = 'R2GMX96108X4BTMR'
ts = TimeSeries(key)
aapl, meta = ts.get_daily(symbol='AAPL')
# print(json.dumps(aapl, indent=4))
print(aapl['2020-01-02'])
# Out:
# 2020-05-08 21:15:28,053 : 959 : DEBUG : Starting new HTTPS connection (1): www.alphavantage.co:443
# 2020-05-08 21:15:28,191 : 437 : DEBUG : https://www.alphavantage.co:443 "GET /query?function=TIME_SERIES_DAILY&symbol=AAPL&outputsize=compact&apikey=R2GMX96108X4BTMR&datatype=json HTTP/1.1" 200 None
# {'1. open': '296.2400', '2. high': '300.6000', '3. low': '295.1900', '4. close': '300.3500', '5. volume': '33911864'}

# %%
# #US Bureau of Labor Statistics\
areaCodesDF = pd.read_csv("bureauoflaborstats.csv")
fips_dict = pd.read_csv("fipscodes.csv")
fips_dict = fips_dict[["State Abbreviation","FIPS Code"]]
fips_dict = fips_dict.to_dict()

#If we want to get more granular, we can switch the area_type_code from A to N
areaCodesList = areaCodesDF[areaCodesDF["area_type_code"]=="A"]
areaCodesList = list(areaCodesList["area_code"].values)

master_unemp_DF = pd.DataFrame({"year":[],"periodName":[],"value":[],"state":[]})

for x in areaCodesList:
    try:
        seriesid = f"LAU{x}03"
        fips_code = x[2:4]
        headers = {'Content-type': 'application/json'} 
        data = json.dumps({"seriesid": [seriesid],"startyear":"2010", "endyear":"2020","registrationkey":"99dc14b091ad411393d936e7b627945f"})
        response = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers).json()
        state_unemp_DF = pd.DataFrame(response['Results']['series'][0]['data'])
        state_unemp_DF['state'] = fips_dict['State Abbreviation'][int(fips_code)]
        state_unemp_DF = state_unemp_DF[["year","periodName","value","state"]]
        state_unemp_DF['value'] = state_unemp_DF['value'].astype('float')
        master_unemp_DF = master_unemp_DF.append(state_unemp_DF)
    except:
        logging.error(f"Error retrieving data")

master_unemp_DF = pd.pivot_table(master_unemp_DF, index=['state','periodName'], columns=['year'], values=['value'])
master_unemp_DF
# Out:
# 2020-05-08 20:35:33,091 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:33,317 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1387
# 2020-05-08 20:35:33,324 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:33,511 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1373
# 2020-05-08 20:35:33,518 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:33,733 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1338
# 2020-05-08 20:35:33,739 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:33,941 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1365
# 2020-05-08 20:35:33,947 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:34,151 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1358
# 2020-05-08 20:35:34,159 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:34,374 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1367
# 2020-05-08 20:35:34,381 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:34,581 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1361
# 2020-05-08 20:35:34,587 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:34,773 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1374
# 2020-05-08 20:35:34,780 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:34,968 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1366
# 2020-05-08 20:35:34,974 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:35,188 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1371
# 2020-05-08 20:35:35,195 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:35,398 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1372
# 2020-05-08 20:35:35,404 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:35,594 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1362
# 2020-05-08 20:35:35,600 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:35,798 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1342
# 2020-05-08 20:35:35,804 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:35,999 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1349
# 2020-05-08 20:35:36,007 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:36,210 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1362
# 2020-05-08 20:35:36,217 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:36,410 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1333
# 2020-05-08 20:35:36,416 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:36,613 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1339
# 2020-05-08 20:35:36,619 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:36,836 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1348
# 2020-05-08 20:35:36,843 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:37,065 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 1361
# 2020-05-08 20:35:37,071 : 959 : DEBUG : Starting new HTTPS connection (1): api.bls.gov:443
# 2020-05-08 20:35:37,268 : 437 : DEBUG : https://api.bls.gov:443 "POST /publicAPI/v2/timeseries/data/ HTTP/1.1" 200 